# %%
import pytesseract
import cv2
from matplotlib import pyplot as plt

# %%
def display(im_path):
    #https://stackoverflow.com/questions/28816046/displaying-different-images-with-actual-size-in-matplotlib-subplot
    dpi = 80
    im_data = plt.imread(im_path)
    try:
        height, width, depth = im_data.shape
    except:
        height, width = im_data.shape

    # What size does the figure need to be in inches to fit the image?
    figsize = width/ float(dpi), height/float(dpi)

    # Create a figure of the right size with one axes that takes up the full figure
    fig = plt.figure(figsize=figsize)
    ax = fig.add_axes([0, 0, 1, 1])

    # Hide spines, ticks, etc.
    ax.axis('off')

    # Display the image
    ax.imshow(im_data, cmap='gray')

    plt.show()

# %%
image_path =r'C:\Users\Shendy\Documents\Code\electric-sunset\ocr-web-app\Dataset\Receipt_1\1018-receipt.jpg'
image = cv2.imread(image_path)
base_image = image.copy()

display(image_path)

# %%
gray = cv2.cvtColor(base_image, cv2.COLOR_BGR2GRAY)
cv2.imwrite(r'C:\Users\Shendy\Documents\Code\electric-sunset\ocr-web-app\Temp\gray.jpg', gray)
display(r'C:\Users\Shendy\Documents\Code\electric-sunset\ocr-web-app\Temp\gray.jpg')

# %%
# pisahin dengan garis dulu

# %%
result = pytesseract.image_to_string(gray)
print(result)
# Out:
# at 12:49 PM
#
# a |
# 0" Vg GUEST NUMBER 1S
# ne
#
# IN-N-OUT BURGER SANTA CLARA
# 12:48 PM
#
# 2012-04-27
# 176 1 262 1110
#
# Cashier: KEVIN DU
# Check : 12
#
# crannies eR
# HAMB >-00
# W GRX LX TM Inst pro ,
#
# Counter—Take Out
# TAX 8.25% 27 OO
# Amount Due
#
# Cash Tender
# Change $3.00
# THANK you, $.83
#
# 2012-04-27 lr i
# ‘49 PM
